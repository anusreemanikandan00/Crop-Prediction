# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv(r"C:\Users\Anusree\Downloads\Crop_Recommendation.csv")
data
# Out:
#       Nitrogen  Phosphorus  Potassium  Temperature   Humidity  pH_Value  \
# 0           90          42         43    20.879744  82.002744  6.502985
# 1           85          58         41    21.770462  80.319644  7.038096
# 2           60          55         44    23.004459  82.320763  7.840207
# 3           74          35         40    26.491096  80.158363  6.980401
# 4           78          42         42    20.130175  81.604873  7.628473
# ...        ...         ...        ...          ...        ...       ...
# 2195       107          34         32    26.774637  66.413269  6.780064
# 2196        99          15         27    27.417112  56.636362  6.086922
# 2197       118          33         30    24.131797  67.225123  6.362608
# 2198       117          32         34    26.272418  52.127394  6.758793
# 2199       104          18         30    23.603016  60.396475  6.779833
#
#         Rainfall    Crop
# 0     202.935536    Rice
# 1     226.655537    Rice
# ...

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %%
data.head()
# Out:
#    Nitrogen  Phosphorus  Potassium  Temperature   Humidity  pH_Value  \
# 0        90          42         43    20.879744  82.002744  6.502985
# 1        85          58         41    21.770462  80.319644  7.038096
# 2        60          55         44    23.004459  82.320763  7.840207
# 3        74          35         40    26.491096  80.158363  6.980401
# 4        78          42         42    20.130175  81.604873  7.628473
#
#      Rainfall  Crop
# 0  202.935536  Rice
# 1  226.655537  Rice
# 2  263.964248  Rice
# 3  242.864034  Rice
# 4  262.717340  Rice

# %%
data.tail()
# Out:
#       Nitrogen  Phosphorus  Potassium  Temperature   Humidity  pH_Value  \
# 2195       107          34         32    26.774637  66.413269  6.780064
# 2196        99          15         27    27.417112  56.636362  6.086922
# 2197       118          33         30    24.131797  67.225123  6.362608
# 2198       117          32         34    26.272418  52.127394  6.758793
# 2199       104          18         30    23.603016  60.396475  6.779833
#
#         Rainfall    Crop
# 2195  177.774507  Coffee
# 2196  127.924610  Coffee
# 2197  173.322839  Coffee
# 2198  127.175293  Coffee
# 2199  140.937041  Coffee

# %%
data.isna().any()
# Out:
# Nitrogen       False
# Phosphorus     False
# Potassium      False
# Temperature    False
# Humidity       False
# pH_Value       False
# Rainfall       False
# Crop           False
# dtype: bool

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Nitrogen     2200 non-null   int64
#  1   Phosphorus   2200 non-null   int64
#  2   Potassium    2200 non-null   int64
#  3   Temperature  2200 non-null   float64
#  4   Humidity     2200 non-null   float64
#  5   pH_Value     2200 non-null   float64
#  6   Rainfall     2200 non-null   float64
#  7   Crop         2200 non-null   object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 137.6+ KB

# %%
data.duplicated().any()
# Out:
# np.False_

# %%
data.describe()
# Out:
#           Nitrogen   Phosphorus    Potassium  Temperature     Humidity  \
# count  2200.000000  2200.000000  2200.000000  2200.000000  2200.000000
# mean     50.551818    53.362727    48.149091    25.616244    71.481779
# std      36.917334    32.985883    50.647931     5.063749    22.263812
# min       0.000000     5.000000     5.000000     8.825675    14.258040
# 25%      21.000000    28.000000    20.000000    22.769375    60.261953
# 50%      37.000000    51.000000    32.000000    25.598693    80.473146
# 75%      84.250000    68.000000    49.000000    28.561654    89.948771
# max     140.000000   145.000000   205.000000    43.675493    99.981876
#
#           pH_Value     Rainfall
# count  2200.000000  2200.000000
# mean      6.469480   103.463655
# std       0.773938    54.958389
# min       3.504752    20.211267
# 25%       5.971693    64.551686
# 50%       6.425045    94.867624
# 75%       6.923643   124.267508
# max       9.935091   298.560117

# %% [markdown]
# # VISUALISING DATA BY MATPLOTLIB

# %%
data1=data.drop(['Nitrogen','Phosphorus','Potassium','Temperature','Humidity','Rainfall',],axis=1)
data1
# Out:
#       pH_Value    Crop
# 0     6.502985    Rice
# 1     7.038096    Rice
# 2     7.840207    Rice
# 3     6.980401    Rice
# 4     7.628473    Rice
# ...        ...     ...
# 2195  6.780064  Coffee
# 2196  6.086922  Coffee
# 2197  6.362608  Coffee
# 2198  6.758793  Coffee
# 2199  6.779833  Coffee
#
# [2200 rows x 2 columns]

# %%
plt.figure(figsize=(12,6))
plt.plot(data['Crop'],data['pH_Value'],color='#800000',label='Crop',marker='s')
plt.xlabel('C R O P')
plt.ylabel('p H _ V A L U E')
plt.title('crop prediction')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### SETTING TARGET VALUE

# %%
x=data.drop(['Crop'],axis=1)
y=data['Crop']

# %%
y
# Out:
# 0         Rice
# 1         Rice
# 2         Rice
# 3         Rice
# 4         Rice
#          ...
# 2195    Coffee
# 2196    Coffee
# 2197    Coffee
# 2198    Coffee
# 2199    Coffee
# Name: Crop, Length: 2200, dtype: object

# %%
x
# Out:
#       Nitrogen  Phosphorus  Potassium  Temperature   Humidity  pH_Value  \
# 0           90          42         43    20.879744  82.002744  6.502985
# 1           85          58         41    21.770462  80.319644  7.038096
# 2           60          55         44    23.004459  82.320763  7.840207
# 3           74          35         40    26.491096  80.158363  6.980401
# 4           78          42         42    20.130175  81.604873  7.628473
# ...        ...         ...        ...          ...        ...       ...
# 2195       107          34         32    26.774637  66.413269  6.780064
# 2196        99          15         27    27.417112  56.636362  6.086922
# 2197       118          33         30    24.131797  67.225123  6.362608
# 2198       117          32         34    26.272418  52.127394  6.758793
# 2199       104          18         30    23.603016  60.396475  6.779833
#
#         Rainfall
# 0     202.935536
# 1     226.655537
# 2     263.964248
# 3     242.864034
# ...

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
ytrain
# Out:
# 1102     Mango
# 1159     Mango
# 141      Maize
# 1004    Banana
# 2         Rice
#          ...
# 1638    Orange
# 1095    Banana
# 1130     Mango
# 1294    Grapes
# 860     Lentil
# Name: Crop, Length: 1540, dtype: object

# %%
xtrain
# Out:
#       Nitrogen  Phosphorus  Potassium  Temperature   Humidity  pH_Value  \
# 1102        21          26         27    27.003155  47.675254  5.699587
# 1159        29          35         28    28.347161  53.539031  6.967418
# 141         60          44         23    24.794708  70.045567  5.722580
# 1004        80          77         49    26.054330  79.396545  5.519088
# 2           60          55         44    23.004459  82.320763  7.840207
# ...        ...         ...        ...          ...        ...       ...
# 1638        10           5          5    21.213070  91.353492  7.817846
# 1095       108          94         47    27.359116  84.546250  6.387431
# 1130        11          36         31    27.920633  51.779659  6.475449
# 1294        11         124        204    13.429886  80.066340  6.361141
# 860         32          78         22    23.970814  62.355576  7.007038
#
#         Rainfall
# 1102   95.851183
# 1159   90.402604
# 141    76.728601
# 1004  113.229737
# ...

# %% [markdown]
# # MODEL FITTING

# %% [markdown]
# ## LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()

# %%
model.fit(xtrain,ytrain)
# Out:
# LogisticRegression()

# %%
poi=model.predict(xtest)
poi
# Out:
# array(['Muskmelon', 'Watermelon', 'Papaya', 'Papaya', 'Apple', 'Mango',
#        'Apple', 'MothBeans', 'MungBean', 'Lentil', 'Blackgram', 'Coconut',
#        'Pomegranate', 'Jute', 'Coconut', 'Pomegranate', 'Apple', 'Cotton',
#        'Papaya', 'Muskmelon', 'Coffee', 'Papaya', 'Orange', 'Papaya',
#        'ChickPea', 'Jute', 'MungBean', 'Orange', 'PigeonPeas', 'Rice',
#        'Pomegranate', 'MothBeans', 'Jute', 'Lentil', 'Jute', 'Blackgram',
#        'Jute', 'ChickPea', 'ChickPea', 'KidneyBeans', 'Papaya', 'Mango',
#        'Blackgram', 'Maize', 'MungBean', 'Maize', 'PigeonPeas', 'Coconut',
#        'Muskmelon', 'Maize', 'Blackgram', 'Coffee', 'Grapes', 'MungBean',
#        'Coffee', 'KidneyBeans', 'Cotton', 'Apple', 'Banana', 'Lentil',
#        'Watermelon', 'Coconut', 'Lentil', 'Orange', 'Papaya', 'Blackgram',
#        'Orange', 'Rice', 'Muskmelon', 'PigeonPeas', 'Muskmelon',
#        'Coconut', 'Jute', 'Banana', 'Blackgram', 'Papaya', 'Banana',
# ...

# %%
Logistictrain=model.score(xtrain,ytrain)*100
Logistictrain
# Out:
# 97.40259740259741

# %%
Logistictest=model.score(xtest,ytest)*100
Logistictest
# Out:
# 94.6969696969697

# %% [markdown]
# ## DecisionTreeClassifier

# %%
from sklearn.tree import DecisionTreeClassifier
model2=DecisionTreeClassifier()
model2.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier()

# %%
DecisionTreetrain=model2.score(xtrain,ytrain)*100
DecisionTreetrain
# Out:
# 100.0

# %%
DecisionTreetest=model2.score(xtest,ytest)*100
DecisionTreetest
# Out:
# 98.33333333333333

# %% [markdown]
# ## RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier
model3=RandomForestClassifier(n_estimators=100)
model3.fit(xtrain,ytrain)
# Out:
# RandomForestClassifier()

# %%
RandomForestTrain=model3.score(xtrain,ytrain)*100
RandomForestTrain
# Out:
# 100.0

# %%
RandomForestTest=model3.score(xtest,ytest)*100
RandomForestTest
# Out:
# 99.0909090909091

# %% [markdown]
# ## AdaBoostClassifier

# %%
from sklearn.ensemble import AdaBoostClassifier
model4=AdaBoostClassifier(n_estimators=50)
model4.fit(xtrain,ytrain)
# Out:
# AdaBoostClassifier()

# %%
AdaBoosttrain=model4.score(xtrain,ytrain)*100
AdaBoosttrain
# Out:
# 18.961038961038962

# %%
AdaBoosttest=model4.score(xtest,ytest)*100
AdaBoosttest
# Out:
# 19.242424242424242

# %% [markdown]
# ## GradientBoostingClassifier

# %%
from sklearn.ensemble import GradientBoostingClassifier
model5=GradientBoostingClassifier(n_estimators=50)
model5.fit(xtrain,ytrain)
# Out:
# GradientBoostingClassifier(n_estimators=50)

# %%
GradientBoostingtrain=model5.score(xtrain,ytrain)*100
GradientBoostingtrain
# Out:
# 100.0

# %%
GradientBoostingtest=model5.score(xtest,ytest)*100
GradientBoostingtest
# Out:
# 98.33333333333333

# %% [markdown]
# ## KNeighborsClassifier

# %%
from sklearn.neighbors import KNeighborsClassifier
model6= KNeighborsClassifier(n_neighbors=5)
model6.fit(xtrain,ytrain)
# Out:
# KNeighborsClassifier()

# %%
KNeighborstrain=model6.score(xtrain,ytrain)*100
KNeighborstrain
# Out:
# 99.0909090909091

# %%
KNeighborstest=model6.score(xtest,ytest)*100
KNeighborstest
# Out:
# 97.72727272727273

# %% [markdown]
# ## GaussianNB

# %%
from sklearn.naive_bayes  import GaussianNB
model7=GaussianNB()

# %%
model7.fit(xtrain,ytrain)
# Out:
# GaussianNB()

# %%
GaussianNBtrain=model7.score(xtrain,ytrain)*100
GaussianNBtrain
# Out:
# 99.54545454545455

# %%
GaussianNBtest=model7.score(xtest,ytest)*100
GaussianNBtest
# Out:
# 99.39393939393939

# %% [markdown]
# # PREDICTION

# %%
Nitrogen=int(input("Enter the Nitrogen"))
Nitrogen
# Out:
# Enter the Nitrogen 12
# 12

# %%
Phosphorus=int(input("Enter the Phosphorus"))
Phosphorus
# Out:
# Enter the Phosphorus 34
# 34

# %%
Potassium=int(input("Enter the Potassium"))
Potassium
# Out:
# Enter the Potassium 45
# 45

# %%
Temperature=float(input("Enter the Temperature"))
Temperature
# Out:
# Enter the Temperature 23
# 23.0

# %%
Humidity=float(input("Enter the Humidity"))
Humidity
# Out:
# Enter the Humidity 14
# 14.0

# %%
pH_Value=int(input("Enter the pH_Value"))
pH_Value
# Out:
# Enter the pH_Value 75
# 75

# %%
Rainfall=int(input("Enter the Rainfall"))
Rainfall
# Out:
# Enter the Rainfall 45
# 45

# %%
print(model3.predict([[Nitrogen,Phosphorus,Potassium,Temperature,Humidity,pH_Value,Rainfall]]))
# Out:
# ['ChickPea']

# %% [markdown]
# # BUILD GRADIO INTERFACE

# %%
# !pip3 install gradio
#user interface

# %%
def fun(Nitrogen,Phosphorus,Pottassium,Teperature,Humidity,pH_Value,Rainfall):
    pred=model3.predict([[Nitrogen,Phosphorus,Pottassium,Teperature,Humidity,pH_Value,Rainfall]])
    return pred

    #fun(Nitrogen,Phosphorus,Pottassium,Teperature,Humidity,pH_Value,Rainfall)

# %%
import gradio as gr

# %%
headline="Crop Prediction App"
iface=gr.Interface(fn=fun,inputs=[
    gr.Textbox(label="Nitrogen"),
    gr.Textbox(label="Phosphours"),
    gr.Textbox(label="potassium"),
    gr.Textbox(label="Temperature"),
    gr.Textbox(label="Humidity"),
    gr.Textbox(label="pH_Value"),
    gr.Textbox(label="Rainfall")],
    outputs=[gr.Textbox(label="crop")],title=headline,css=".gradio-container{background-color :#ff5733;}")
iface.launch(share=True)


#change background clr
#,css=".gradio-container{background-color:#ff5733;}"
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://a979375de1a9fdbf48.gradio.live
#
# This share link is temporary and will last for up to 1 week (best effort). For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://a979375de1a9fdbf48.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
